# %%
import requests
import csv
import pandas as pd
import re

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Part 1: Data Extraction

# %% [markdown]
# ## Football Data API

# %%
base_url = "https://api.football-data.org/v4"
pl_seasons_url = f"{base_url}/competitions/PL/matches?season=2022"
pl_teams_url = f"{base_url}/competitions/PL/teams?season=2022"
headers = {"X-Auth-Token": "e956ca357099455ca05a437c205e24e6"} #TODO: get from env variable

# %% [markdown]
# ### Extract & Format Premier League Team Data

# %%
teeam_response = requests.get(pl_teams_url, headers=headers)
pl_team_data = teeam_response.json()

# %%
season_response = requests.get(pl_seasons_url, headers=headers)
season_data = season_response.json()

# %%
season_data['matches'][1]['utcDate']
# Out:
# '2022-08-06T11:30:00Z'

# %%
season_data_df = pd.DataFrame(season_data['matches'])

# %%
req_cols = ['id', 'utcDate', 'status', 'homeTeam', 'awayTeam', 'score']

# %%
season_data_df = season_data_df[req_cols]
season_data_df.head(2)
# Out:
#        id               utcDate    status  \
# 0  416384  2022-08-05T19:00:00Z  FINISHED
# 1  416383  2022-08-06T11:30:00Z  FINISHED
#
#                                             homeTeam  \
# 0  {'id': 354, 'name': 'Crystal Palace FC', 'shor...
# 1  {'id': 63, 'name': 'Fulham FC', 'shortName': '...
#
#                                             awayTeam  \
# 0  {'id': 57, 'name': 'Arsenal FC', 'shortName': ...
# 1  {'id': 64, 'name': 'Liverpool FC', 'shortName'...
#
#                                                score
# 0  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...
# 1  {'winner': 'DRAW', 'duration': 'REGULAR', 'ful...

# %%
home_team = pd.json_normalize(season_data_df['homeTeam']).add_prefix('home_team_')
away_team = pd.json_normalize(season_data_df['awayTeam']).add_prefix('away_team_')
score = pd.json_normalize(season_data_df['score']).add_prefix('score_')

# %%
score
# Out:
#     score_winner score_duration  score_fullTime.home  score_fullTime.away  \
# 0      AWAY_TEAM        REGULAR                    0                    2
# 1           DRAW        REGULAR                    2                    2
# 2      HOME_TEAM        REGULAR                    4                    1
# 3      HOME_TEAM        REGULAR                    2                    0
# 4      HOME_TEAM        REGULAR                    2                    1
# ..           ...            ...                  ...                  ...
# 375         DRAW        REGULAR                    1                    1
# 376         DRAW        REGULAR                    1                    1
# 377    HOME_TEAM        REGULAR                    1                    0
# 378    HOME_TEAM        REGULAR                    2                    1
# 379    HOME_TEAM        REGULAR                    5                    0
#
#      score_halfTime.home  score_halfTime.away
# 0                      0                    1
# 1                      1                    0
# 2                      2                    1
# 3                      0                    0
# 4                      1                    1
# ..                   ...                  ...
# 375                    0                    1
# 376                    1                    1
# 377                    0                    0
# 378                    2                    1
# 379                    3                    0
#
# [380 rows x 6 columns]

# %%
pl_teams = [
    {
    "id": team["id"], 
    "name": team["name"],
    "shortName": team["shortName"],
    "address": team["address"]
    } 
    for team in pl_team_data["teams"]
]

# %%
pl_teams_df = pd.read_csv("resources/data/pl_teams.csv")

# %%
set(pl_teams_df['city'])
# Out:
# {'Birmingham',
#  'Bournemouth',
#  'Brentford',
#  'Brighton & Hove',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'London',
#  'Manchester',
#  'Newcastle upon Tyne',
#  'Nottingham',
#  'Southampton',
#  'Wolverhampton'}

# %%
import urllib.parse

cities = {'Birmingham', 'Bournemouth', 'Brentford', 'Brighton & Hove', 'Leeds', 'Leicester', 
          'Liverpool', 'London', 'Manchester', 'Newcastle upon Tyne', 'Nottingham', 'Southampton', 'Wolverhampton'}

encoded_cities = {urllib.parse.quote(city) for city in cities}

print(encoded_cities)
# Out:
# {'Birmingham', 'Liverpool', 'Brighton%20%26%20Hove', 'Leeds', 'Newcastle%20upon%20Tyne', 'London', 'Manchester', 'Bournemouth', 'Southampton', 'Nottingham', 'Wolverhampton', 'Leicester', 'Brentford'}

# %%
unique_cities = set(pd.read_csv("resources/data/pl_teams.csv")["city"])

# %%
unique_cities = {urllib.parse.quote(city) for city in unique_cities}

# %%
unique_cities
# Out:
# {'Birmingham',
#  'Bournemouth',
#  'Brentford',
#  'Brighton%20%26%20Hove',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'London',
#  'Manchester',
#  'Newcastle%20upon%20Tyne',
#  'Nottingham',
#  'Southampton',
#  'Wolverhampton'}

# %% [markdown]
# # Weather data

# %%
START_DATE = "2022-05-01"
END_DATE = "2023-06-01"

BASE = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline"
TIME = f"{START_DATE}/{END_DATE}"
PARAMS = "?unitGroup=metric&key=NKSZZCF5RF5HEK47WQWRA8NC8&contentType=json"

# %%
for city in unique_cities:
    BASE_URL = f"{BASE}/{city}/{TIME}?{PARAMS}"
#     requests.get(BASE_URL)

# %%
url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Newcastle%20upon%20Tyne/2022-05-01/2023-06-01?unitGroup=metric&key=X8XBGA475B5W32MGBLXS8KEYW&contentType=json"

# %%
res = requests.get(url)

# %%
data = res.json()

# %%
data.keys()
# Out:
# dict_keys(['queryCost', 'latitude', 'longitude', 'resolvedAddress', 'address', 'timezone', 'tzoffset', 'days', 'stations'])

# %%
days_df = pd.DataFrame(data['days'])

# %%
days_df
# Out:
#        datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0    2022-05-01     1651359600     14.7      8.7  11.5          14.7
# 1    2022-05-02     1651446000     11.6      7.8  10.1          11.6
# 2    2022-05-03     1651532400     11.0      6.9   8.9          11.0
# 3    2022-05-04     1651618800     16.8      6.2  11.6          16.8
# 4    2022-05-05     1651705200     14.9      5.7  11.0          14.9
# ..          ...            ...      ...      ...   ...           ...
# 392  2023-05-28     1685228400     14.0      6.2  11.0          14.0
# 393  2023-05-29     1685314800     17.0      3.0  10.8          17.0
# 394  2023-05-30     1685401200     15.1      4.2  10.5          15.1
# 395  2023-05-31     1685487600     13.1      9.9  11.3          13.1
# 396  2023-06-01     1685574000     12.0      6.9  10.3          12.0
#
#      feelslikemin  feelslike  dew  humidity  precip  precipprob  precipcover  \
# 0             7.7       11.3  8.5      82.4   5.678       100.0        33.33
# 1             6.9        9.5  7.1      82.5   0.106       100.0        20.83
# 2             6.0        8.4  6.5      85.7   0.703       100.0        20.83
# 3             6.2       11.3  8.7      83.4   3.568       100.0        37.50
# 4             2.9       10.2  7.8      80.8   0.157       100.0         4.17
# ..            ...        ...  ...       ...     ...         ...          ...
# 392           6.2       10.7  5.9      72.4   0.000         0.0         0.00
# 393           3.0       10.8  5.4      72.8   0.000         0.0         0.00
# 394           4.2       10.5  7.2      80.7   0.000         0.0         0.00
# 395           8.5       11.2  7.6      78.1   0.000         0.0         0.00
# 396           6.8        9.9  7.0      80.7   0.010       100.0         4.17
#
#     preciptype  snow  snowdepth  windgust  windspeed  winddir  pressure  \
# 0       [rain]   0.0        0.0      14.8        8.6    184.7    1020.0
# 1       [rain]   0.0        0.0      24.3       14.8      9.1    1021.9
# 2       [rain]   0.0        0.0      18.0       10.7    132.1    1021.1
# 3       [rain]   0.0        0.0      37.6       22.2    259.3    1015.2
# 4       [rain]   0.0        0.0      31.0       19.3    266.0    1021.4
# ..         ...   ...        ...       ...        ...      ...       ...
# 392     [rain]   0.0        0.0      30.9       23.3     62.8    1027.6
# 393       None   0.0        0.0      24.5       13.0     98.6    1031.1
# 394       None   0.0        0.0      22.0       12.9     69.3    1033.1
# 395       None   0.0        0.0      20.9       14.4     65.5    1031.5
# 396     [rain]   0.0        0.0      36.0       20.5     36.4    1029.3
#
#      cloudcover  visibility  solarradiation  solarenergy  uvindex  severerisk  \
# 0          70.4        17.9           141.2         12.1      5.0        10.0
# 1          79.2        13.9            65.5          5.6      2.0        10.0
# 2          81.3        10.0            78.8          6.6      2.0        10.0
# 3          58.5        14.9           168.0         14.4      5.0        10.0
# 4          54.4        18.5           137.3         11.9      6.0        10.0
# ..          ...         ...             ...          ...      ...         ...
# 392        55.0        12.2           172.1         14.8      7.0        10.0
# 393         5.3        12.8           303.5         26.1      8.0        10.0
# 394        49.7        12.4           185.2         16.0      6.0        10.0
# 395        88.1        13.8           124.0         10.6      3.0        10.0
# 396        90.1        12.8            97.9          8.3      3.0        10.0
#
#       sunrise  sunriseEpoch    sunset  sunsetEpoch  moonphase  \
# 0    05:26:41    1651379201  20:41:46   1651434106       0.02
# 1    05:24:33    1651465473  20:43:40   1651520620       0.05
# 2    05:22:25    1651551745  20:45:35   1651607135       0.09
# 3    05:20:20    1651638020  20:47:29   1651693649       0.12
# 4    05:18:15    1651724295  20:49:23   1651780163       0.15
# ..        ...           ...       ...          ...        ...
# 392  04:40:04    1685245204  21:28:22   1685305702       0.28
# 393  04:38:53    1685331533  21:29:46   1685392186       0.32
# 394  04:37:45    1685417865  21:31:09   1685478669       0.35
# 395  04:36:40    1685504200  21:32:29   1685565149       0.38
# 396  04:35:38    1685590538  21:33:47   1685651627       0.41
#
#                  conditions  \
# 0    Rain, Partially cloudy
# 1    Rain, Partially cloudy
# 2    Rain, Partially cloudy
# 3    Rain, Partially cloudy
# 4    Rain, Partially cloudy
# ..                      ...
# 392        Partially cloudy
# 393                   Clear
# 394        Partially cloudy
# 395        Partially cloudy
# 396          Rain, Overcast
#
#                                            description               icon  \
# 0    Partly cloudy throughout the day with a chance...               rain
# 1          Partly cloudy throughout the day with rain.               rain
# 2    Partly cloudy throughout the day with a chance...               rain
# 3    Partly cloudy throughout the day with a chance...               rain
# 4    Partly cloudy throughout the day with morning ...               rain
# ..                                                 ...                ...
# 392                  Partly cloudy throughout the day.  partly-cloudy-day
# 393               Clear conditions throughout the day.          clear-day
# 394                  Partly cloudy throughout the day.  partly-cloudy-day
# 395                  Partly cloudy throughout the day.  partly-cloudy-day
# 396  Cloudy skies throughout the day with morning r...               rain
#
#                                               stations source  \
# 0    [03275099999, 03243399999, EGNT, D7177, 032400...    obs
# 1    [03275099999, 03243399999, EGNT, D7177, 032400...    obs
# 2    [03275099999, 03243399999, EGNT, D7177, 032400...    obs
# 3    [03275099999, 03243399999, EGNT, D7177, 032400...    obs
# 4    [03275099999, 03243399999, EGNT, D7177, 032400...    obs
# ..                                                 ...    ...
# 392  [03243399999, 03275099999, EGNT, D7177, 032300...    obs
# 393  [03243399999, 03275099999, EGNT, D7177, 032300...    obs
# 394  [03243399999, 03275099999, EGNT, D7177, 032300...    obs
# 395  [03243399999, 03275099999, EGNT, D7177, 032300...    obs
# 396  [03243399999, 03275099999, EGNT, D7177, 032300...    obs
#
#                                                  hours  tzoffset
# 0    [{'datetime': '00:00:00', 'datetimeEpoch': 165...       NaN
# 1    [{'datetime': '00:00:00', 'datetimeEpoch': 165...       NaN
# 2    [{'datetime': '00:00:00', 'datetimeEpoch': 165...       NaN
# 3    [{'datetime': '00:00:00', 'datetimeEpoch': 165...       NaN
# 4    [{'datetime': '00:00:00', 'datetimeEpoch': 165...       NaN
# ..                                                 ...       ...
# 392  [{'datetime': '00:00:00', 'datetimeEpoch': 168...       NaN
# 393  [{'datetime': '00:00:00', 'datetimeEpoch': 168...       NaN
# 394  [{'datetime': '00:00:00', 'datetimeEpoch': 168...       NaN
# 395  [{'datetime': '00:00:00', 'datetimeEpoch': 168...       NaN
# 396  [{'datetime': '00:00:00', 'datetimeEpoch': 168...       NaN
#
# [397 rows x 38 columns]

# %%
required_cols = ["datetime", "temp", "humidity", "precip", "windspeed"]

# %%
new_df = days_df[required_cols]

# %%
new_df
# Out:
#        datetime  temp  humidity  precip  windspeed
# 0    2022-05-01  11.5      82.4   5.678        8.6
# 1    2022-05-02  10.1      82.5   0.106       14.8
# 2    2022-05-03   8.9      85.7   0.703       10.7
# 3    2022-05-04  11.6      83.4   3.568       22.2
# 4    2022-05-05  11.0      80.8   0.157       19.3
# ..          ...   ...       ...     ...        ...
# 392  2023-05-28  11.0      72.4   0.000       23.3
# 393  2023-05-29  10.8      72.8   0.000       13.0
# 394  2023-05-30  10.5      80.7   0.000       12.9
# 395  2023-05-31  11.3      78.1   0.000       14.4
# 396  2023-06-01  10.3      80.7   0.010       20.5
#
# [397 rows x 5 columns]

# %%
urllib.parse.unquote("Newcastle%20upon%20Tyne")
# Out:
# 'Newcastle upon Tyne'

# %%
new_df.loc[:, 'city'] = urllib.parse.unquote("Newcastle%20upon%20Tyne")

# %%
new_df
# Out:
#        datetime  temp  humidity  precip  windspeed                 city
# 0    2022-05-01  11.5      82.4   5.678        8.6  Newcastle upon Tyne
# 1    2022-05-02  10.1      82.5   0.106       14.8  Newcastle upon Tyne
# 2    2022-05-03   8.9      85.7   0.703       10.7  Newcastle upon Tyne
# 3    2022-05-04  11.6      83.4   3.568       22.2  Newcastle upon Tyne
# 4    2022-05-05  11.0      80.8   0.157       19.3  Newcastle upon Tyne
# ..          ...   ...       ...     ...        ...                  ...
# 392  2023-05-28  11.0      72.4   0.000       23.3  Newcastle upon Tyne
# 393  2023-05-29  10.8      72.8   0.000       13.0  Newcastle upon Tyne
# 394  2023-05-30  10.5      80.7   0.000       12.9  Newcastle upon Tyne
# 395  2023-05-31  11.3      78.1   0.000       14.4  Newcastle upon Tyne
# 396  2023-06-01  10.3      80.7   0.010       20.5  Newcastle upon Tyne
#
# [397 rows x 6 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   datetime   397 non-null    object
#  1   temp       397 non-null    float64
#  2   humidity   397 non-null    float64
#  3   precip     397 non-null    float64
#  4   windspeed  397 non-null    float64
#  5   city       397 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 18.7+ KB
